# %% [markdown]
# <a href="https://colab.research.google.com/github/praju-007anchan/IN126060102_NPL/blob/main/NLP_task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Task 1: Conceptual Understanding
#
# Answer the following questions in your own words:
#
# 1.What is the difference between "Love" and "love" in NLP?
#
# 2.What happens if stopwords are not removed?
#
# 3.Provide two real-world scenarios where removing stopwords can be harmful.
#
# 4.Explain the difference between stemming and lemmatization.

# %% [markdown]
# 1.In NLP, "Love" and "love" are treated as different tokens because text is case-sensitive by default.Without normalization,
#
# "Love" → may appear at sentence start
# "love" → common verb or noun

# %% [markdown]
# 2.Stopwords (like is, the, and) appear very frequently but carry little meaning.
#
# If not removed:
#
# Model gets noisy data
# Increased processing time
# Important words get less weight
# Reduced model performance

# %% [markdown]
# 3.1. Changes meaning
#
# Example: "I am not happy"
# Remove "not" → "I happy"(wrong meaning)
#
# 2. Breaks sentence meaning
#
# Example: "To be or not to be"
# Remove words → "be not be"(confusing)

# %% [markdown]
# 4.1 Stemming
#
# Stemming is the process of cutting words to their base form by removing endings.
#
# It uses simple rules (not smart)
# The output may not be a real word
#
# Example:
#
# "running" → "runn"
# "playing" → "play"
#
# 4.2 Lemmatization is the process of converting a word to its correct base form (root word).
#
# It uses a dictionary
# The output is always a meaningful word
#
#  Example:
#
# "running" → "run"
# "better" → "good"

# %% [markdown]
# Task 2: Advanced Preprocessing Function

# %%
import re

def preprocess_text(text):
    if not text or text.strip() == "":
        return [], ""

    # Remove URLs
    text = re.sub(r'http\S+|www\S+', '', text)

    # Remove emails
    text = re.sub(r'\S+@\S+', '', text)

    # Remove numbers
    text = re.sub(r'\d+', '', text)

    # Lowercase
    text = text.lower()

    # Handle repeated characters
    text = re.sub(r'(.)\1{2,}', r'\1', text)

    # Remove special characters
    text = re.sub(r'[^a-z\s]', '', text)

    # Remove extra spaces
    text = re.sub(r'\s+', ' ', text).strip()

    # Tokenize
    tokens = text.split()

    # Remove short words except 'no', 'not'
    tokens = [w for w in tokens if len(w) > 2 or w in ['no', 'not']]

    cleaned_sentence = " ".join(tokens)

    return tokens, cleaned_sentence

# %% [markdown]
# Task 3: Stress Testing

# %%
sentences = [
    "Get 100% FREE access now!!!",
    "I absolutely looooved this product 😍😍",
    "Worst service ever... 0/10",
    "Call me at 9876543210",
    "This is THE best course!!!",
    "Visit https://openai.com now!",
    "Nooooo this is baaad!!!",
    "OK OK OK I got it",
    "Win $$$ now!!! Limited offer!!!",
    "I am not happy with this"
]

for s in sentences:
    tokens, clean = preprocess_text(s)
    print("Original:", s)
    print("Tokens:", tokens)
    print("Cleaned:", clean)
    print("-"*50)
# Out:
# Original: Get 100% FREE access now!!!
# Tokens: ['get', 'free', 'access', 'now']
# Cleaned: get free access now
# --------------------------------------------------
# Original: I absolutely looooved this product 😍😍
# Tokens: ['absolutely', 'loved', 'this', 'product']
# Cleaned: absolutely loved this product
# --------------------------------------------------
# Original: Worst service ever... 0/10
# Tokens: ['worst', 'service', 'ever']
# Cleaned: worst service ever
# --------------------------------------------------
# Original: Call me at 9876543210
# Tokens: ['call']
# Cleaned: call
# --------------------------------------------------
# Original: This is THE best course!!!
# Tokens: ['this', 'the', 'best', 'course']
# Cleaned: this the best course
# --------------------------------------------------
# Original: Visit https://openai.com now!
# Tokens: ['visit', 'now']
# Cleaned: visit now
# --------------------------------------------------
# Original: Nooooo this is baaad!!!
# ...

# %% [markdown]
# Task 4: Token Analytics

# %%
for s in sentences:
    tokens, _ = preprocess_text(s)

    total = len(tokens)
    unique = len(set(tokens))
    avg_len = sum(len(w) for w in tokens)/total if total > 0 else 0

    print("Sentence:", s)
    print("Total Tokens:", total)
    print("Unique Tokens:", unique)
    print("Avg Length:", round(avg_len,2))
    print("-"*40)
# Out:
# Sentence: Get 100% FREE access now!!!
# Total Tokens: 4
# Unique Tokens: 4
# Avg Length: 4.0
# ----------------------------------------
# Sentence: I absolutely looooved this product 😍😍
# Total Tokens: 4
# Unique Tokens: 4
# Avg Length: 6.5
# ----------------------------------------
# Sentence: Worst service ever... 0/10
# Total Tokens: 3
# Unique Tokens: 3
# Avg Length: 5.33
# ----------------------------------------
# Sentence: Call me at 9876543210
# Total Tokens: 1
# Unique Tokens: 1
# Avg Length: 4.0
# ----------------------------------------
# Sentence: This is THE best course!!!
# Total Tokens: 4
# Unique Tokens: 4
# Avg Length: 4.25
# ----------------------------------------
# Sentence: Visit https://openai.com now!
# Total Tokens: 2
# Unique Tokens: 2
# Avg Length: 4.0
# ----------------------------------------
# Sentence: Nooooo this is baaad!!!
# Total Tokens: 3
# Unique Tokens: 3
# Avg Length: 3.0
# ----------------------------------------
# Sentence: OK OK OK I got it
# ...

# %% [markdown]
# Task 5: Frequency Analysis Output

# %%
from collections import Counter

all_tokens = []
for s in sentences:
    tokens, _ = preprocess_text(s)
    all_tokens.extend(tokens)

counter = Counter(all_tokens)

print("Top 10:", counter.most_common(10))
print("Least 5:", counter.most_common()[-5:])
# Out:
# Top 10: [('this', 4), ('now', 3), ('get', 1), ('free', 1), ('access', 1), ('absolutely', 1), ('loved', 1), ('product', 1), ('worst', 1), ('service', 1)]
# Least 5: [('limited', 1), ('offer', 1), ('not', 1), ('happy', 1), ('with', 1)]

# %% [markdown]
# Task 6: Full Pipeline

# %%
def full_pipeline(text_list):
    all_tokens = []
    clean_sentences = []

    for text in text_list:
        tokens, clean = preprocess_text(text)
        all_tokens.extend(tokens)
        clean_sentences.append(clean)

    return {
        "tokens": all_tokens,
        "clean_sentences": clean_sentences
    }

# %%
result = full_pipeline(sentences)
print(result)
# Out:
# {'tokens': ['get', 'free', 'access', 'now', 'absolutely', 'loved', 'this', 'product', 'worst', 'service', 'ever', 'call', 'this', 'the', 'best', 'course', 'visit', 'now', 'no', 'this', 'bad', 'got', 'win', 'now', 'limited', 'offer', 'not', 'happy', 'with', 'this'], 'clean_sentences': ['get free access now', 'absolutely loved this product', 'worst service ever', 'call', 'this the best course', 'visit now', 'no this bad', 'got', 'win now limited offer', 'not happy with this']}

# %% [markdown]
# Task 7: Error Handling Output

# %%
print(preprocess_text(""))
print(preprocess_text("😂😂😂"))
print(preprocess_text("123456"))
# Out:
# ([], '')
# ([], '')
# ([], '')
